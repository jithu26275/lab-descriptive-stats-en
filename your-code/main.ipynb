# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# YOUR CODE HERE
temp = pd.read_csv(r"C:\Users\JITHIN\OneDrive\Desktop\Bootcamp\Bootcamp_Labs\week_4\d2_lab2\lab-descriptive-stats-en\your-code\Temp_States.csv")

# %% [markdown]
# #### Print `temp`

# %%
# your solution here
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# YOUR CODE HERE
temp.info()
print(temp.dtypes) # this helps to find missing or null values and also the types of data frama with City and State is object type and Temparature is float
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# YOUR CODE HERE
New_york = temp[temp["State"] == "New York"]
New_york
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# YOUR CODE HERE
avg_temp_newyork = New_york["Temperature"].mean()
avg_temp_newyork
# Out:
# np.float64(10.74074074074074)

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp_abv_15_dg = temp["Temperature"] > 15 
filter_temp = temp[temp_abv_15_dg]
filter_temp
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# YOUR CODE HERE
fil_city_15_deg = filter_temp["City"]
fil_city_15_deg
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# YOUR CODE HERE
city_btwn_15to20_deg = (temp["Temperature"] > 15) & (temp["Temperature"] < 20)
filter_city_15to20 = temp[city_btwn_15to20_deg]
filter_city_15to20
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %%
temp['State'].value_counts()
# Out:
# State
# New York       3
# Connecticut    2
# New Jersey     2
# Name: count, dtype: int64

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# YOUR CODE HERE
state_temp_stats = temp.groupby('State')['Temperature'].agg(['mean', 'std'])
print(state_temp_stats)
# Out:
#                   mean       std
# State
# Connecticut  15.833333  1.964186
# New Jersey   21.111111  1.571348
# New York     10.740741  8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# YOUR CODE HERE
employee = pd.read_csv(r"C:\Users\JITHIN\OneDrive\Desktop\Bootcamp\Bootcamp_Labs\week_4\d2_lab2\lab-descriptive-stats-en\your-code\Employee.csv")

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# YOUR CODE HERE
employee.info()
print(employee.dtypes) # 7 columns all having 9 non null values , years and salary are having int values and others are object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        9 non-null      object
#  1   Department  9 non-null      object
#  2   Education   9 non-null      object
#  3   Gender      9 non-null      object
#  4   Title       9 non-null      object
#  5   Years       9 non-null      int64
#  6   Salary      9 non-null      int64
# dtypes: int64(2), object(5)
# memory usage: 636.0+ bytes
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
print(employee)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
employee.hist(figsize=(7,5))  # Plot histograms for all numeric columns

plt.tight_layout()  # Adjust layout so plots don't overlap
plt.show()

# %%
# YOUR CODE HERE
sns.histplot(data=employee, x='Salary', bins=10, kde=True, color='skyblue')
plt.title('Salary Distribution with KDE')
plt.show()

# %% [markdown]
# #### What's the average salary in this company?

# %%
# YOUR CODE HERE
avg_salary = employee["Salary"].mean()
avg_salary
# Out:
# np.float64(48.888888888888886)

# %% [markdown]
# #### What's the highest salary?

# %%
# YOUR CODE HERE
high_salary = employee["Salary"].max()
high_salary
# Out:
# np.int64(70)

# %% [markdown]
# #### What's the lowest salary?

# %%
# YOUR CODE HERE
low_salary = employee["Salary"].min()
low_salary
# Out:
# np.int64(30)

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# YOUR CODE HERE
low = employee["Salary"].min()
low_salary_employee = employee[employee["Salary"]== low]
low_salary_employee
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# YOUR CODE HERE
employee_david = employee[employee["Name"]== "David"]
employee_david
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# YOUR CODE HERE
employee_david["Salary"]
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# YOUR CODE HERE
Title_associate = employee[employee["Title"]== "associate"]
Title_associate
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# YOUR CODE HERE
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# YOUR CODE HERE
employee[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# YOUR CODE HERE
employee_associ_55 = (employee["Salary"] > 55) & (employee["Title"]== "associate")
employee_associ_55_sort = employee[employee_associ_55]
employee_associ_55_sort
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# YOUR CODE HERE
years_group = employee.groupby("Years")["Salary"].mean()
years_group
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# YOUR CODE HERE
Title_avg_salary = employee.groupby("Title")["Salary"].mean()
Title_avg_salary
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
#
# * Hint : Quantiles vs Quartiles*
# In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.

# %%
# YOUR CODE HERE

sns.boxplot(x=employee['Salary'], color='skyblue')
plt.title("Salary Distribution - Boxplot")
plt.show()

# %%
# print first quartile here
q1 = employee['Salary'].quantile(0.25)
print("First Quartile (Q1):", q1)
# Out:
# First Quartile (Q1): 35.0

# %%
# print third quartile here
q3 = employee['Salary'].quantile(0.75)
print("Third Quartile (Q3):", q3)
# Out:
# Third Quartile (Q3): 60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
mean_salary = employee.groupby("Gender")["Salary"].mean()
mean_salary #yes its different
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
numeric_cols = employee.select_dtypes(include='number').columns
dept_stats = employee.groupby('Department')[numeric_cols].agg(['min', 'mean', 'max'])

print(dept_stats)
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv(r"C:\Users\JITHIN\OneDrive\Desktop\Bootcamp\Bootcamp_Labs\week_4\d2_lab2\lab-descriptive-stats-en\your-code\Orders.csv")

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.info()
print(orders.dtypes)# 397924 non null values with int float and object type data and 14 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    397924 non-null  int64
#  1   InvoiceNo     397924 non-null  int64
#  2   StockCode     397924 non-null  object
#  3   year          397924 non-null  int64
#  4   month         397924 non-null  int64
#  5   day           397924 non-null  int64
#  6   hour          397924 non-null  int64
#  7   Description   397924 non-null  object
#  8   Quantity      397924 non-null  int64
#  9   InvoiceDate   397924 non-null  object
#  10  UnitPrice     397924 non-null  float64
#  11  CustomerID    397924 non-null  int64
#  12  Country       397924 non-null  object
#  13  amount_spent  397924 non-null  float64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 42.5+ MB
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# ...

# %%
orders.head()
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
avg_purchase_price = orders["UnitPrice"].mean()
avg_purchase_price
# Out:
# np.float64(3.1161744805540756)

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
high_price = orders["UnitPrice"].max()
low_price = orders["UnitPrice"].min()
print(high_price)
print(low_price)
# Out:
# 8142.75
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
cus_spain = orders[orders["Country"]== "Spain"]
cus_spain
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
orders['Country'].value_counts()['Spain']
# Out:
# np.int64(2485)

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
pur_more_50 = orders["Quantity"] > 50
pur_more_50= orders[pur_more_50]
pur_more_50.sort_values(by = "Quantity")
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 147041      211916     555400     20728  2011      6    4    17
# 319887      436433     574143    47518F  2011     11    4    11
# 204622      291834     562521     20897  2011      8    5    12
# 2344          3513     536634     21080  2010     12    4    11
# 188617      270680     560580     23245  2011      7    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 143243      206121     554868     22197  2011      5    5    10
# 308128      421632     573008     84077  2011     10    4    12
# 370473      502122     578841     84826  2011     11    5    15
# 37126        61619     541431     23166  2011      1    2    10
# 397451      540421     581483     23843  2011     12    5     9
#
#                                 Description  Quantity          InvoiceDate  \
# 147041                  lunch bag cars blue        51  2011-06-02 17:50:00
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
spain_abv_50 = pur_more_50[pur_more_50["Country"]== "Spain"]
spain_abv_50
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
free_orders = orders[orders["amount_spent"]== 0 ]
free_orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
lunch_bag = orders[orders["Description"].str.contains('lunch bag', case=False, na=False)]
lunch_bag
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
lunch_bag_2011 = lunch_bag[lunch_bag["year"]== 2011]
lunch_bag_2011
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
spain_amounts = orders[orders['Country'] == 'Spain']['amount_spent']
frequency_distribution = spain_amounts.value_counts().sort_index()
print(frequency_distribution)
# Out:
# amount_spent
# 0.00       1
# 0.21       3
# 0.29       1
# 0.39       3
# 0.42       1
#           ..
# 417.50     1
# 488.16     2
# 1080.00    1
# 1220.40    2
# 1350.00    3
# Name: count, Length: 316, dtype: int64

# %%
# your answer here
spain_amounts = orders[orders['Country'] == 'Spain']['amount_spent']

plt.hist(spain_amounts, bins=20)  # You can adjust bins as needed
plt.title('Frequency Distribution of Amount Spent in Spain')
plt.xlabel('Amount Spent')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
order_aug = orders[orders["month"]== 8]
order_aug
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
aug_countries = order_aug["Country"]
aug_countries.value_counts()
# Out:
# Country
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: count, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
country_spent = orders.groupby("Country")["amount_spent"].mean().reset_index(name="avg_spent")
country_spent
# Out:
#                  Country   avg_spent
# 0              Australia  116.895620
# 1                Austria   25.624824
# 2                Bahrain   32.258824
# 3                Belgium   20.283772
# 4                 Brazil   35.737500
# 5                 Canada   24.280662
# 6        Channel Islands   27.340160
# 7                 Cyprus   22.134169
# 8         Czech Republic   33.069600
# 9                Denmark   49.882474
# 10                  EIRE   36.687745
# 11    European Community   21.670833
# 12               Finland   32.913985
# 13                France   25.056827
# 14               Germany   25.311562
# 15                Greece   32.831172
# 16               Iceland   23.681319
# 17                Israel   29.119718
# 18                 Italy   23.064960
# 19                 Japan  116.561900
# 20               Lebanon   37.641778
# 21             Lithuania   47.458857
# 22                 Malta   24.335625
# 23           Netherlands  120.798282
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
most_expensive_item = orders.loc[orders['UnitPrice'].idxmax()]
print(most_expensive_item[['Description', 'UnitPrice']])
# Out:
# Description    postage
# UnitPrice      8142.75
# Name: 118352, dtype: object

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
avg_year_spent = orders.groupby("year")["amount_spent"].mean()
avg_year_spent
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
